# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import plotly.express as px
from sklearn.decomposition import PCA

# %%
df = pd.read_csv(r"C:\Users\MSİ\Desktop\archive (4)\Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
df.Id.nunique()
# Out:
# 150

# %%
df.drop("Id", axis=1, inplace=True)

# %%
df.describe().T
# Out:
#                count      mean       std  min  25%   50%  75%  max
# SepalLengthCm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# SepalWidthCm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# PetalLengthCm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# PetalWidthCm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
df[df.duplicated()]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 34             4.9           3.1            1.5           0.1     Iris-setosa
# 37             4.9           3.1            1.5           0.1     Iris-setosa
# 142            5.8           2.7            5.1           1.9  Iris-virginica

# %%
df = df[~df.duplicated()]

# %% [markdown]
# We can olso use this code df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.Species.value_counts()
# Out:
# Species
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: count, dtype: int64

# %%
col_viz = ["SepalLengthCm"  , "SepalWidthCm" , "PetalLengthCm" , "PetalWidthCm"]
for i in col_viz:
    print("Skew" , round(df[i].skew() , 2))
    plt.subplot(1 , 2 , 1)
    df[i].hist()
    plt.subplot(1 , 2 , 2)
    sns.boxplot(x = df[i])
    plt.show()
# Out:
# Skew 0.29
# Skew 0.32
# Skew -0.29
# Skew -0.11

# %%
num_col = df.select_dtypes(include = "number")
sns.heatmap(num_col.corr() , annot=True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()
df.Species = lb.fit_transform(df["Species"])

# %%
from sklearn.model_selection import  train_test_split

# %%
x = df.drop("Species", axis=1)
y = df["Species"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
n = x_train.shape[1]
pca = PCA(n_components = n , random_state = 42)
df_pca = pd.DataFrame(pca.fit_transform(x_train))
exp_var = pca.explained_variance_ratio_

# %%
plt.figure(figsize = (10,10))
plt.plot(range(1,5), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title("Explained Variances by Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
pc_comps = ['PC1','PC2']
data_pca = pd.DataFrame(np.round(pca.components_[:2,:],2),index=pc_comps,columns=x_train.columns)
data_pca.T
# Out:
#                 PC1   PC2
# SepalLengthCm  0.36  0.63
# SepalWidthCm  -0.08  0.75
# PetalLengthCm  0.86 -0.17
# PetalWidthCm   0.35 -0.06

# %%
pca = PCA(n_components = 2 , random_state = 42)
x_train_PCA = pca.fit_transform(x_train)
x_test_PCA = pca.transform(x_test)

# %%
from sklearn.metrics import confusion_matrix , classification_report
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))

    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))

    sns.heatmap(cm, annot=True,  fmt='.2f')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()
lg.fit(x_train_PCA , y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = lg.predict(x_train_PCA)
metrics_score(y_train , y_pred_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       0.97      0.95      0.96        40
#            2       0.95      0.97      0.96        40
#
#     accuracy                           0.97       117
#    macro avg       0.98      0.97      0.97       117
# weighted avg       0.97      0.97      0.97       117

# %%
y_pred_test = lg.predict(x_test_PCA)
metrics_score(y_test, y_pred_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.75      0.90      0.82        10
#            2       0.86      0.67      0.75         9
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.86      0.86        30
# weighted avg       0.87      0.87      0.86        30

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(x_train_PCA , y_train)
# Out:
# SVC()

# %%
y_pred_trains = svc.predict(x_train_PCA)
metrics_score(y_train , y_pred_trains)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       0.97      0.95      0.96        40
#            2       0.95      0.97      0.96        40
#
#     accuracy                           0.97       117
#    macro avg       0.98      0.97      0.97       117
# weighted avg       0.97      0.97      0.97       117

# %%
y_pred_testss = svc.predict(x_test_PCA)
metrics_score(y_test , y_pred_testss)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.75      0.90      0.82        10
#            2       0.86      0.67      0.75         9
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.86      0.86        30
# weighted avg       0.87      0.87      0.86        30

# %%
svc_linear = SVC(kernel = "linear")
svc_linear.fit(x_train_PCA , y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_tr = svc_linear.predict(x_train_PCA)
metrics_score(y_train , y_pred_tr)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        37
#            1       0.97      0.95      0.96        40
#            2       0.95      0.97      0.96        40
#
#     accuracy                           0.97       117
#    macro avg       0.98      0.97      0.97       117
# weighted avg       0.97      0.97      0.97       117

# %%
y_pred_te = svc_linear.predict(x_test_PCA)
metrics_score(y_test , y_pred_te)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.75      0.90      0.82        10
#            2       0.86      0.67      0.75         9
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.86      0.86        30
# weighted avg       0.87      0.87      0.86        30
